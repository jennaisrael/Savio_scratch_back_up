# %%
import numpy as np 
import sys

    
import xarray as xr 
import matplotlib.pyplot as plt 

print("Modules imported")
# Out:
# Modules imported

# %%
narr=xr.open_dataset("//global/scratch/users/jennaisrael/BayDeltaSCHISM/data/atmosphere/NARR/2017_10/narr_air.2017_10_01.nc")

# %%
narr=roms

# %%
narr.head()
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 5, ny_grid: 5, nx_grid: 5)
# Coordinates:
#   * time     (time) datetime64[ns] 2017-10-01 ... 2017-10-01T12:00:00
# Dimensions without coordinates: ny_grid, nx_grid
# Data variables:
#     lon      (ny_grid, nx_grid) float32 ...
#     lat      (ny_grid, nx_grid) float32 ...
#     uwind    (time, ny_grid, nx_grid) float32 ...
#     vwind    (time, ny_grid, nx_grid) float32 ...
#     prmsl    (time, ny_grid, nx_grid) float32 ...
#     stmp     (time, ny_grid, nx_grid) float32 ...
#     spfh     (time, ny_grid, nx_grid) float32 ...

# %%
print(narr['lon'].values) #VALUES converts to numpy
# Out:
# [[-123.735886 -123.39491  -123.05324  -122.710884 -122.36786  -122.024185
#   -121.679855 -121.3349   -120.98933  -120.64315  -120.29638  -119.94903
#   -119.60111  -119.25265 ]
#  [-123.81376  -123.4713   -123.128136 -122.78428  -122.43975  -122.09455
#   -121.7487   -121.40221  -121.05509  -120.70736  -120.359024 -120.01011
#   -119.660614 -119.31056 ]
#  [-123.89234  -123.54839  -123.20373  -122.85836  -122.51231  -122.16557
#   -121.818184 -121.470146 -121.12147  -120.77217  -120.42226  -120.071754
#   -119.72067  -119.369026]
#  [-123.97166  -123.6262   -123.280014 -122.93312  -122.58553  -122.23726
#   -121.88831  -121.53871  -121.18846  -120.837585 -120.48609  -120.13399
#   -119.7813   -119.42804 ]
#  [-124.051704 -123.70473  -123.35702  -123.00858  -122.65945  -122.309616
#   -121.95911  -121.607925 -121.256096 -120.90362  -120.55052  -120.19681
#   -119.84251  -119.48761 ]
#  [-124.13249  -123.78399  -123.43474  -123.084755 -122.734055 -122.38265
# ...

# %%
125.16407-125.07348
# Out:
# 0.09058999999999173

# %%
roms=xr.open_dataset("/global/scratch/users/jennaisrael/BayDeltaSCHISM/data/ROMS/ROMS_cleaned/2018cencoos_ca_roms_20180102.nc")

# %%
roms.head()
# Out:
# <xarray.Dataset>
# Dimensions:  (depth: 5, lat: 5, lon: 5, time: 5)
# Coordinates:
#   * depth    (depth) float32 0.0 10.0 20.0 30.0 40.0
#   * lat      (lat) float32 37.3 37.33 37.36 37.39 37.42
#   * lon      (lon) float32 236.5 236.5 236.6 236.6 236.6
#   * time     (time) datetime64[ns] 2018-01-02 ... 2018-01-02T04:00:00
# Data variables:
#     salt     (time, depth, lat, lon) float64 ...
#     temp     (time, depth, lat, lon) float64 ...
#     u        (time, depth, lat, lon) float64 ...
#     v        (time, depth, lat, lon) float64 ...
#     zeta     (time, lat, lon) float64 ...
# Attributes: (12/18)
#     history:                  Fri Sep 18 02:27:06 2020: ncatted -O -aunits,ti...
#     type:                     ROMS REAL TIME FORECASTING
#     fileid:                   SOUTH CALIFORNIA BIGHT
#     title:                    California ROMS Nowcast (3km)
#     summary:                  The California ROMS model extends from just nor...
# ...

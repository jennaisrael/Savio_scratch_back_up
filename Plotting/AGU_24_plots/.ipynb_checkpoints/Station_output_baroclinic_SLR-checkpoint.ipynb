# %%
import numpy as np 
import sys

    
import xarray as xr 
import matplotlib.pyplot as plt 
import matplotlib.dates as mdates 
import matplotlib as mpl
from scipy import signal #for filtering
print("Modules imported")
# Out:
# Modules imported

# %%
# velocity = data.horizontalVelX.isel(time=40, nSCHISM_vgrid_layers=0).values

import re 
file="/global/scratch/users/jennaisrael/run_schism/run_26/station.in"
station_id =[]
with open(file) as f:
    f.readline()
    for station in range(int(f.readline())):
        line = f.readline()
        if '!' in line:
            station_id.append(line.split('!')[-1])
        else:
            station_id.append(None)
# print(station_id)

print(len(station_id))

stations = []
for sublist in station_id:
    match = re.search(r'"(.*?)"', sublist)
    if match:
        stations.append(match.group(1).strip())
    else :
        stations.append(sublist.replace("\n", "").strip())
print(len(set(stations)))


for i, station in enumerate(stations):
    print("%d == %s" % (i,station))
# Out:
# 263
# 240
# 0 == San Joaquin at Antioch
# 1 == Mokelumne River at Benson's Ferry
# 2 == Cache Slough
# 3 == Old River at Coney Island
# 4 == Clifton Court
# 5 == Discovery Bay at Indian Slough
# 6 == Doughty Cut above Grant Line Canal
# 7 == Sacramento River at Emmaton
# 8 == EMM upper Emmaton
# 9 == EMM lower Emmaton
# 10 == Farrar Park
# 11 == Grant Line Canal at Tracy Rd Bridge
# 12 == Green's Landing
# 13 == Harvey O Banks PP
# 14 == Holland Tract
# 15 == Harvey O Banks PP
# 16 == CCWD Old River near Discovery Bay
# 17 == CCWD Rock Slough PP
# 18 == Italian Slough Headwater near Byron
# 19 == Jersey Point
# 20 == Sacramento River at Mallard Island
# 21 == Sacramento River at Mallard Island
# 22 == Middle River at Howard Rd Bridge
# 23 == San Joaquin at Mossdale Bridge
# 24 == Middle River at Tracy Blvd
# 25 == Old River Barrier near DMC (Above)
# 26 == Old River below Dam
# 27 == Old River at Bacon Island
# 28 == Old River at Head
# 29 == Old River at Byron
# 30 == Prisoners Point
# 31 == Rock Slough at Contra Costa Canal
# 32 == San Andreas Landing
# 33 == San Joaquin River Mccune Station near Vernalis
# 34 == Mokelumne River (South Fork) @ Staten Island
# 35 == Sacramento River at Threemile Slough
# 36 == Tom Paine Sl above intake
# 37 == Tom Paine Sl near Pescadero
# 38 == Tom Paine Sl above the mouth
# 39 == Tracy Pumping Plant
# 40 == Union Island
# 41 == Victoria Island
# 42 == Barker Slough Pumping Plant
# 43 == Venice Island
# 44 == Sacramento River at Collinsville
# 45 == Sacramento River at Hood
# 46 == Sacramento River at Rio Vista
# 47 == Sacramento River at Martinez
# 48 == Sacramento River at Martinez
# 49 == Chadbourne Slough at Sunrise Duck Club
# 50 == Goodyear Slough at Morrow Island club
# 51 == Suisun Slough 300' south of Volanti Slough
# 52 == Montezuma Slough near Beldons Landing
# 53 == Cordelia Slough at Ibis club
# 54 == Yolo Bypass at Lisbon
# 55 == West Canal near Clifton Court Intake
# 56 == Old River near Clifton Court Intake
# 57 == Ridge Cut Slough at Knight's Landing
# 58 == Montezuma Slough at National Steel
# 59 == Montezuma Slough at National Steel
# 60 == San Joaquin River near Lathrop
# 61 == San Joaquin River at Brandt Bridge
# 62 == Stockton Ship Channel at Burns Cut-off
# 63 == Stockton Ship Channel at Burns Cut-off
# 64 == Middle River at Undine Road
# 65 == Old River at Tracy Blvd
# 66 == Southampton Shoal Channel LB 6
# 67 == Tiburon Pier
# 68 == China Camp
# 69 == San Francisco
# 70 == AAMC1 default Alameda
# 71 == San Mateo Bridge
# 72 == Redwood City
# 73 == Dumbarton Bridge
# 74 == Coyote Creek
# 75 == RICHM default Richmond
# 76 == ANC upper Antioch
# 77 == ANC lower Antioch
# 78 == CLL upper Collinsville
# 79 == CLL lower Collinsville
# 80 == Contra Costa
# 81 == PTS upper PIttsburg
# 82 == PTS lower PIttsburg
# 83 == Rio Vista
# 84 == VER default Vernalis
# 85 == Port Chicago
# 86 == SF Bay at San Mateo Bridge Near Foster City, CA
# 87 == SF Bay at San Mateo Bridge Near Foster City, CA
# 88 == Guadalupe R above Hw 101 at San Jose, CA
# 89 == Coyote Creek above HW 237
# 90 == San Joaquin R near Vernalis
# 91 == San Joaquin R below Garwood Bridge
# 92 == Turner Cut near Holt
# 93 == Victoria Canal near Byron
# 94 == Middle R at Middle River
# 95 == Middle R near Holt
# 96 == Old R near Delta Mendota Canal
# 97 == Grantline Canal
# 98 == Old R near Byron
# 99 == Old R at Bacon Island
# 100 == Holland Cut near Bethel Island
# 101 == Dutch Sl below Jersey Island
# 102 == Old R at Quimby Island
# 103 == False R near Oakley
# 104 == Old R at Franks Tract
# 105 == San Joaquin R at Prisoners Pt
# 106 == Delta Cross Channel near Walnut Grove
# 107 == Little Potato Slough at Terminous
# 108 == Mokelumne R at Andrus Island
# 109 == Threemile Slough near Rio Vista
# 110 == San Joaquin R at Jersey Point
# 111 == Sacramento R at Freeport
# 112 == Sutter Slough at Courtland
# 113 == Steamboat Slough btw Sacramento R and Sutter Sl
# 114 == Sacramento R above Delta Cross Channel
# 115 == Georgiana Slough near Sacramento R
# 116 == Sacramento R below Georgiana Slough
# 117 == Toe Drain at Liberty Island near Courtland
# 118 == Liberty Cut at Liberty Island near Courtland
# 119 == Miner Slough at HW 84 Bridge
# 120 == Shag Slough at Liberty Island near Courtland
# 121 == Sacramento R Deep Water Ship Channel Near Rio Vista
# 122 == Cache Slough at Ryer Island
# 123 == Sacramento R at Rio Vista
# 124 == Suisun Bay at Benicia Bridge
# 125 == Suisun Bay at Benicia Bridge
# 126 == Carquinez Strait at Carquinez Bridge near Crockett
# 127 == Carquinez Strait at Carquinez Bridge near Crockett
# 128 == Napa R near Napa
# 129 == Petaluma R at Copland Pumping Station
# 130 == San Francisco Bay at Old Dumbarton Bridge
# 131 == San Francisco Bay at Old Dumbarton Bridge
# 132 == San Francisco Bay at Richmond-San Rafael Bridge
# 133 == San Francisco Bay at Richmond-San Rafael Bridge
# 134 == Mare Island
# 135 == CROCK default Crockett
# 136 == Port Chicago
# 137 == Bradmoor Island
# 138 == Mallard Island Ferry Wharf
# 139 == ANTN default Antioch
# 140 == Rio Vista
# 141 == San Joaquin River at Rindge Pump
# 142 == Sacramento R at I Street
# 143 == Georgiana Slough at Mokelumne R
# 144 == Sacramento R at Walnut Grove
# 145 == Sacramento R at Snodgrass
# 146 == Threemile Slough at San Joaquin R
# 147 == Threemile Slough near San Joaquin River
# 148 == Grantline Canal above Dam
# 149 == Old R at Clifton Court Ferry
# 150 == Middle R at Bacon Island
# 151 == Middle R at Middle R
# 152 == Middle River at Union Point
# 153 == Middle R at Mowry
# 154 == Turner Cut near Holt
# 155 == Victoria Canal near Byron
# 156 == Middle R near Holt
# 157 == Grant Line Canal near Clifton Court Forebay - WQ
# 158 == Holland Cut near Bethel Island
# 159 == Old R at Quimby Island
# 160 == False R near Oakley
# 161 == Old R at Franks Tract
# 162 == Mokelumne River near Highway 12
# 163 == Steamboat Slough Below Sutter Slough
# 164 == Old River at Tracy Wildlife Association
# 165 == Rock Slough at Delta Road Bridge
# 166 == Holland Cut at Holland Marina
# 167 == Werner Dredger Cut near Palm Tract
# 168 == Piper Slough at Bethal Tract
# 169 == San Joaquin River at Blind Point
# 170 == Rough and Ready Island
# 171 == San Joaquin at Antioch
# 172 == San Joaquin at Antioch
# 173 == San Joaquin at Mossdale Bridge
# 174 == Sacramento River at Fremont Weir (West End)
# 175 == Sacramento River at Fremont Weir (East End)
# 176 == Sacramento River at Knights Landing
# 177 == DMC Headworks
# 178 == Sugar Cut
# 179 == Grant Line Canal East
# 180 == Middle River above Barrier
# 181 == Old River above Doughty Cut
# 182 == San Joaquin River above Dos Reis
# 183 == San Francisco Bay at Northeast Shore Alcatraz Island
# 184 == Middle River near Howard Rd Bridge
# 185 == Decker Island
# 186 == Decker Island
# 187 == Cache Slough at Liberty Island
# 188 == Yolo Bypass at Liberty Island
# 189 == Yolo Bypass at Liberty Island (Canal)
# 190 == S Mokelumne R at New Hope BR near Walnut Grove
# 191 == N Mokelumne R near Walnut Grove
# 192 == Steamboat Slough near Sacramento River
# 193 == Fisherman's Cut
# 194 == Sacramento River Downstream of Isleton
# 195 == Miner Slough
# 196 == San Joaquin River at Twitchell Island
# 197 == Sacramento River near Sherman Island
# 198 == Bethel Island at Piper Slough
# 199 == Franks Tract, Mid Tract
# 200 == Honker Bay
# 201 == Suisun Bay Cutoff Near Ryer
# 202 == Grizzly Bay
# 203 == Sugar Cut at Golden Anchor
# 204 == Sacramento River at Verona
# 205 == S.F. Mokelumne River at New Hope Bridge
# 206 == Miner Slough at Five Points
# 207 == Toe Drain at Mallard Road
# 208 == Sacramento River Deep Water Ship Channel Near Freeport
# 209 == Sacramento River Deep Water Ship Channel Near Clarksburg
# 210 == Ulatis Creek Near Elmira
# 211 == Cache Slough Near Hastings Tract Near Rio Vista
# 212 == Cache Slough Above Ryer Island Ferry
# 213 == Suisun Bay At Van Sickle Island
# 214 == Hass Slough Near Elmira
# 215 == Grizzly Bay at Suisun Slough
# 216 == Grizzly Bay at Head of Montezuma Slough Buoy
# 217 == Yolo Bypass Near Woodland
# 218 == Grant Line Canal Near Tracy
# 219 == Sacramento River Deep Water Ship Channel Near Courtland
# 220 == Suisun Bay at Mallard Island
# 221 == First Mallard Branch
# 222 == Lisbon Weir
# 223 == Miner Slough Near Sacramento River and Prospect Island
# 224 == Montezuma Slough Above Grizzly Bay
# 225 == Liberty Cut at Liberty Island
# 226 == Alviso Slough
# 227 == Coyote Creek at confluence with Alviso slough
# 228 == Dumbarton Bridge near surface
# 229 == Guadalupe Slough
# 230 == Mowry Slough
# 231 == Newark Slough
# 232 == Pond A8 Outlet at Confluence with Alviso Slough
# 233 == San Mateo Bridge near surface
# 234 == Sacramento Weir Spill to Yolo Bypass
# 235 == San Francisco Bay at Pier 17
# 236 == Martinez-Amorco Pier
# 237 == Alviso Slough Near Alviso
# 238 == South San Francisco Bay at Dumbarton Bridge
# 239 == Corte Madera Creek Near Larkspur
# 240 == Old River upstream of Mountain House Creek
# 241 == Paradise Cut Above Old River
# 242 == Paradise Cut
# 243 == Paradise Cut Upstream - WQ
# 244 == San Joaquin River near Buckley Cove
# 245 == San Joaquin River at D.V.I. Pump
# 246 == Blacklock (NE1)
# 247 == Cygnus-Cordelia Slough
# 248 == Godfather II on Suisun Slough
# 249 == Hunter Cut at Montezuma Slough
# 250 == Montezuma Slough at Roaring River
# 251 == Grizzly Bay Buoy
# 252 == Alameda Creek Flood Channel at Union City
# 253 == Teal Club at Frank Horan Slough
# 254 == Hill Slough
# 255 == Liberty Island at Upper Stair Step
# 256 == Prospect Slough Near Five Points
# 257 == Toe Drain at Five Points
# 258 == Little Holland Tract at North Breach Near Holland Tract
# 259 == Prospect Slough at Toe Drain Near Courtland
# 260 == Cache Slough below Shag Slough
# 261 == Liberty Cut at Five Points
# 262 == Liberty Cut at Holland Tract

# %%
import pandas as pd

columns = ['time']
stations_no = [str(i) for i in range(263)]
columns = columns + stations_no



# These outputs are invoked with iout_sta=1, and are found in outputs/staout_[1..,9], corresponding respectively to elev, air pressure, wind u, wind v, T, S, u, v, w. Each output has a simple ASCII format:
# Time(sec), variable @ station 1,2,…. (specified in station.in)

#file="//global/scratch/users/jennaisrael/run_schism/run_8/outputs_barotropic/staout_1"
file="//global/scratch/users/jennaisrael/run_schism/run_26/outputs/staout_1"# 1:elev,2:air pressure,3:wind_x,4:wind_y,5:temp,6:salt,7:u,8:v,9:w
data = pd.read_csv(file, sep='\s+', names=columns) #, decode_times=False)
data = data.apply(pd.to_numeric)

 
# Add in the number of seconds elapsed @ our chosen timestep
timedelta = [pd.Timedelta(i, unit = 's') for i in data.time]
timestamp = [pd.to_datetime("03-30-2014 00:00") + i for i in timedelta]
    
data["time"] = timestamp

# %%
data
# Out:
#                      time         0        1         2         3         4  \
# 0     2014-03-30 00:15:00  0.980225  1.04381  0.996266  0.974619  0.970298
# 1     2014-03-30 00:30:00  0.975780  1.06806  1.024320  0.985046  0.970056
# 2     2014-03-30 00:45:00  0.981232  1.04160  1.058370  0.984014  0.969779
# 3     2014-03-30 01:00:00  0.994228  1.01371  1.085700  0.982071  0.969456
# 4     2014-03-30 01:15:00  1.011790  1.00285  1.094770  0.980154  0.969018
# ...                   ...       ...      ...       ...       ...       ...
# 20345 2014-10-27 22:30:00  0.697594  1.52881  1.313640  1.496250  1.195130
# 20346 2014-10-27 22:45:00  0.652746  1.49207  1.267530  1.456310  1.193860
# 20347 2014-10-27 23:00:00  0.610781  1.45597  1.221570  1.415490  1.192590
# 20348 2014-10-27 23:15:00  0.570816  1.42054  1.175510  1.374390  1.191310
# 20349 2014-10-27 23:30:00  0.533896  1.38556  1.130380  1.333440  1.190040
#
#               5         6         7         8  ...     253       254      255  \
# 0      0.976395  0.996294  0.980206  0.980206  ... -9999.0  1.032100  1.38272
# 1      0.975350  1.004180  0.995365  0.995365  ... -9999.0  0.995910  1.18407
# 2      0.974578  1.026540  1.007620  1.007620  ... -9999.0  1.018070  1.12868
# 3      0.973694  1.035500  1.009720  1.009720  ... -9999.0  1.007000  1.11126
# 4      0.973805  1.029600  1.027990  1.027990  ... -9999.0  1.001440  1.09738
# ...         ...       ...       ...       ...  ...     ...       ...      ...
# 20345  1.422190  1.727280  0.705465  0.705465  ... -9999.0  0.450937  1.39798
# 20346  1.381080  1.707040  0.657174  0.657174  ... -9999.0  0.401734  1.35773
# 20347  1.339810  1.686540  0.612408  0.612408  ... -9999.0  0.355778  1.31619
# 20348  1.298590  1.664890  0.569279  0.569279  ... -9999.0  0.312426  1.27282
# 20349  1.257620  1.642640  0.530191  0.530191  ... -9999.0  0.274154  1.22869
#
#             256      257      258      259       260      261      262
# 0      1.025290  1.19751  1.43919  1.43919  1.046220  1.17839  1.48217
# 1      1.087330  1.13930  1.31426  1.31426  1.096140  1.12604  1.20750
# 2      1.092670  1.12129  1.23556  1.23556  1.100130  1.10972  1.10738
# 3      1.074600  1.10261  1.18015  1.18015  1.082130  1.09355  1.07473
# 4      1.062680  1.08534  1.14841  1.14841  1.068670  1.08050  1.07786
# ...         ...      ...      ...      ...       ...      ...      ...
# 20345  1.145850  1.29066  1.40784  1.40784  1.186290  1.27321  1.30128
# 20346  1.094180  1.24256  1.36587  1.36587  1.133960  1.22443  1.25192
# 20347  1.042560  1.19556  1.32435  1.32435  1.081670  1.17659  1.20468
# 20348  0.991859  1.14842  1.28261  1.28261  1.030320  1.12968  1.15631
# 20349  0.942028  1.10568  1.24147  1.24147  0.979383  1.08774  1.10966
#
# [20350 rows x 264 columns]

# %%
# Make a plot
plt.ioff()

#station_indices=[0, 208, 2, 62, 105]
#station_indices=[47,48,56,7,8,9] #first are 2 martinez, then Old River near Clifton court intake, last 3 are emmaton
station_indices=[8,9]#47,48,56,7,8,9,]
fig = plt.figure(figsize=(11,6))
ax = plt.gca()
# ax.grid(alpha=0.5)
for idx in station_indices:
    values = data[str(idx)]
    ax.plot(data.time, values, label = stations[idx], linewidth=2, alpha =0.7)
    

leg = ax.legend()
print(ax)
ax.set_xlim(data.time.iloc[0], data.time.iloc[-1])
# ax.grid(which='major', color='b', linestyle='-')
ax.set_title("Elevation for baroclinic run")
plt.show()
# ax.grid()
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
file="//global/scratch/users/jennaisrael/run_schism/run_26/outputs/staout_5" #1:elev,2:air pressure,3:wind_x,4:wind_y,5:temp,6:salt,7:u,8:v,9:w
data = pd.read_csv(file, sep='\s+', names=columns) #, decode_times=False)
data = data.apply(pd.to_numeric)

 
# Add in the number of seconds elapsed @ our chosen timestep
timedelta = [pd.Timedelta(i, unit = 's') for i in data.time]
timestamp = [pd.to_datetime("03-30-2014 00:00") + i for i in timedelta]
    
data["time"] = timestamp


fig = plt.figure(figsize=(11,6))
ax = plt.gca()
# ax.grid(alpha=0.5)
for idx in station_indices:
    values = data[str(idx)]
    ax.plot(data.time, values, label = stations[idx], linewidth=2, alpha =0.7)
    

leg = ax.legend()
print(ax)
ax.set_xlim(data.time.iloc[0], data.time.iloc[-1])
# ax.grid(which='major', color='b', linestyle='-')
ax.set_title("Temperature from baroclinic run")
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%d-%Y'))
plt.show()
# ax.grid()
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
file="//global/scratch/users/jennaisrael/run_schism/run_26/outputs/staout_6" #1:elev,2:air pressure,3:wind_x,4:wind_y,5:temp,6:salt,7:u,8:v,9:w
data = pd.read_csv(file, sep='\s+', names=columns) #, decode_times=False)
data = data.apply(pd.to_numeric)

 
# Add in the number of seconds elapsed @ our chosen timestep
timedelta = [pd.Timedelta(i, unit = 's') for i in data.time]
timestamp = [pd.to_datetime("03-30-2014 00:00") + i for i in timedelta]
    
data["time"] = timestamp


fig = plt.figure(figsize=(11,6))
ax = plt.gca()
# ax.grid(alpha=0.5)
for idx in station_indices:
    values = data[str(idx)]
    ax.plot(data.time, values, label = stations[idx], linewidth=2, alpha =0.7)
    

leg = ax.legend()
print(ax)
ax.set_xlim(data.time.iloc[0], data.time.iloc[-1])
# ax.grid(which='major', color='b', linestyle='-')
ax.set_title("Salinity from baroclinic run")
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%d-%Y'))
plt.show()
# ax.grid()
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
#convert from PSU to uS/cm (at Emmaton the limit is 1000 uS/cm)
from vtools.functions.unit_conversions import cfs_to_cms, ft_to_m, ec_psu_25c, fahrenheit_to_celsius
std= ec_psu_25c(1000)
print(std)
# Out:
# /global/home/users/jennaisrael/.conda/envs/schimpy/lib/python3.7/site-packages/dask/dataframe/utils.py:15: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# 0.4919575246252693

# %%
#make a plot with upper Emmaton from the historical and 2 slr studies with a line for the standard
#set the x axis to exclude the first 90 days

file1="//global/scratch/users/jennaisrael/run_schism/run_26/outputs/staout_6" #1:elev,2:air pressure,3:wind_x,4:wind_y,5:temp,6:salt,7:u,8:v,9:w
file2="//global/scratch/users/jennaisrael/run_schism/run_25/outputs/staout_6"
file3="//global/scratch/users/jennaisrael/run_schism/run_27/outputs/staout_6"
data1 = pd.read_csv(file1, sep='\s+', names=columns) #, decode_times=False)
data1 = data1.apply(pd.to_numeric)
data2 = pd.read_csv(file2, sep='\s+', names=columns) #, decode_times=False)
data2 = data2.apply(pd.to_numeric)
data3 = pd.read_csv(file3, sep='\s+', names=columns) #, decode_times=False)
data3 = data3.apply(pd.to_numeric)

 
# Add in the number of seconds elapsed @ our chosen timestep
timedelta1 = [pd.Timedelta(i, unit = 's') for i in data1.time]
timestamp1 = [pd.to_datetime("03-30-2014 00:00") + i for i in timedelta1]    
data1["time"] = timestamp1

timedelta2 = [pd.Timedelta(i, unit = 's') for i in data2.time]
timestamp2 = [pd.to_datetime("03-30-2014 00:00") + i for i in timedelta2]
data2["time"] = timestamp2

timedelta3 = [pd.Timedelta(i, unit = 's') for i in data3.time]
timestamp3 = [pd.to_datetime("03-30-2014 00:00") + i for i in timedelta3]
data3["time"] = timestamp3

# %%
station_indices=[8]
fig = plt.figure(figsize=(20,6))
mpl.rcParams.update({'font.size': 22})
ax = plt.gca()
# ax.grid(alpha=0.5)
for idx in station_indices:
    values1 = data1[str(idx)]
    values2 = data2[str(idx)]
    values3 = data3[str(idx)]
    ax.plot(data1.time, values1, label = 'Historical', linewidth=2, alpha =0.7)
    ax.plot(data2.time, values2, label = '0.8 m RSLR', linewidth=2, alpha =0.7)
    ax.plot(data3.time, values3, label = '1.2 m RSLR', linewidth=2, alpha =0.7)

ax.plot(data1.time,np.ones_like(values1)*std,linewidth=2, alpha =0.7,linestyle='--',color='k',label='Compliance')

leg = ax.legend()
print(ax)
ax.set_xlim(data1.time.iloc[9000], data3.time.iloc[-1]) #July 1 to end
# ax.grid(which='major', color='b', linestyle='-')
#ax.set_title("Salinity from baroclinic run")
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%d-%Y'))
ax.set_ylabel('Salinity (PSU)')
plt.show()
# ax.grid()
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
station_indices=[8]
fig = plt.figure(figsize=(20,6))
mpl.rcParams.update({'font.size': 22})
ax = plt.gca()
# ax.grid(alpha=0.5)
N=96
for idx in station_indices:
    #running average, currently frequency is every 15 min, so a 24 hr average would be every 96 samples
    
    values1=np.convolve(data1[str(idx)], np.ones(N)/N, mode='valid')
    values2=np.convolve(data2[str(idx)], np.ones(N)/N, mode='valid')
    values3=np.convolve(data3[str(idx)], np.ones(N)/N, mode='valid')
    #lose the first 96 elements so trim the time vector
    ax.plot(data1.time.iloc[95:], values1, label = 'Historical', linewidth=2, alpha =0.7)
    ax.plot(data2.time.iloc[95:], values2, label = '0.8 m RSLR', linewidth=2, alpha =0.7)
    ax.plot(data3.time.iloc[95:], values3, label = '1.2 m RSLR', linewidth=2, alpha =0.7)

ax.plot(data1.time.iloc[95:],np.ones_like(values1)*std,linewidth=2, alpha =0.7,linestyle='--',color='k',label='Compliance')

leg = ax.legend()
#print(ax)
ax.set_xlim(data1.time.iloc[9000], data3.time.iloc[-1]) #July 1 to end
# ax.grid(which='major', color='b', linestyle='-')
#ax.set_title("Salinity from baroclinic run")
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%d-%Y'))
ax.set_ylabel('Salinity (PSU)')
plt.show()
# ax.grid()

# %%
data1.time
# Out:
# 0       2014-03-30 00:15:00
# 1       2014-03-30 00:30:00
# 2       2014-03-30 00:45:00
# 3       2014-03-30 01:00:00
# 4       2014-03-30 01:15:00
#                 ...
# 20345   2014-10-27 22:30:00
# 20346   2014-10-27 22:45:00
# 20347   2014-10-27 23:00:00
# 20348   2014-10-27 23:15:00
# 20349   2014-10-27 23:30:00
# Name: time, Length: 20350, dtype: datetime64[ns]

# %% [raw]
# raw=data1[str(8)]

# %%
#Low pass filter the tidal signal
#sos = signal.butter(4, 6.944*10**-6, 'lp', fs=0.001111, output='sos') #sampling frequency in hz (15 minutes), below 40 hrs
#sos = signal.butter(4, 9.259*10**-6, 'lp', fs=0.001111, output='sos') #sampling frequency in hz (15 minutes), below 30 hrs
#sos = signal.butter(4, 4.6296*10**-6, 'lp', fs=0.001111, output='sos') #sampling frequency in hz (15 minutes), below 60 hrs
sos = signal.butter(4, 3.472*10**-6, 'lp', fs=0.001111, output='sos') #sampling frequency in hz (15 minutes), below 80 hrs
filtered = signal.sosfilt(sos,raw)
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)

ax1.plot(data1.time, raw)

ax1.set_title('Raw Emmaton signal')
ax2.plot(data1.time, filtered)

ax2.set_title('After 60 Hr (4.6296*10**-6) low-pass filter')
plt.show()

# %%
#try 4th order butterworth instead of average

station_indices=[8]
fig = plt.figure(figsize=(20,6))
mpl.rcParams.update({'font.size': 22})
ax = plt.gca()
# ax.grid(alpha=0.5)
#N=96
for idx in station_indices:
    #running average, currently frequency is every 15 min, so a 24 hr average would be every 96 samples
    
    values1=signal.sosfilt(sos,data1[str(idx)])
    values2=signal.sosfilt(sos,data2[str(idx)])
    values3=signal.sosfilt(sos,data3[str(idx)])
    #lose the first 96 elements so trim the time vector
    ax.plot(data1.time, values1, label = 'Historical', linewidth=2, alpha =0.7)
    ax.plot(data2.time, values2, label = '0.8 m RSLR', linewidth=2, alpha =0.7)
    ax.plot(data3.time, values3, label = '1.2 m RSLR', linewidth=2, alpha =0.7)

ax.plot(data1.time,np.ones_like(values1)*std,linewidth=2, alpha =0.7,linestyle='--',color='k',label='Compliance')

leg = ax.legend()
#print(ax)
ax.set_xlim(data1.time.iloc[9000], data3.time.iloc[-1]) #July 1 to end
# ax.grid(which='major', color='b', linestyle='-')
#ax.set_title("Salinity from baroclinic run")
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%d-%Y'))
ax.set_ylabel('Salinity (PSU)')
plt.show()
# ax.grid()

# %%
#find time index of worst daily salinity
ind1=np.argmax(values1[9000:])
print(ind1+9000)
print(data1.time.iloc[ind1+N+9000])
ind2=np.argmax(values2[9000:])
print(ind2+9000)
print(data2.time.iloc[ind2+N+9000])
ind3=np.argmax(values3[9000:])
print(ind3+9000)
print(data3.time.iloc[ind3+N+9000])
#I think they have only all reached 8/23/2014 so pick that date
# Out:
# 19067
# 2014-10-15 15:00:00
# 15944
# 2014-09-13 02:15:00
# 13961
# 2014-08-23 10:30:00

# %%
print(data.time.iloc[0])
print(data.time.iloc[1])
# Out:
# 2014-03-30 00:15:00
# 2014-03-30 00:30:00

# %%
#What about the Value of change in salinity on this date at emmaton,tracy PP, , and franks tract? 
station_indices=[8,55,199]
time_idx=ind3+N+9000
for idx in station_indices:
    #first index the daily average on this day (147th day after start)
    print(data2[str(idx)].iloc[time_idx]-data1[str(idx)].iloc[time_idx])
    print(data3[str(idx)].iloc[time_idx]-data1[str(idx)].iloc[time_idx])
          
    #subtract the SLR scenario from

# %%
#file="//global/scratch/users/jennaisrael/run_schism/run_8/outputs_barotropic/staout_5"
file="//global/scratch/users/jennaisrael/run_schism/run_23/outputs/staout_5"
data = pd.read_csv(file, sep='\s+', names=columns) #, decode_times=False)
data = data.apply(pd.to_numeric)

 
# Add in the number of seconds elapsed @ our chosen timestep
timedelta = [pd.Timedelta(i, unit = 's') for i in data.time]
timestamp = [pd.to_datetime("02-16-2018 00:00") + i for i in timedelta]
    
data["time"] = timestamp

# %%
import matplotlib.dates as mdates 
station_indices=[0, 208, 2, 62, 105]

fig = plt.figure(figsize=(11,6))
ax = plt.gca()
# ax.grid(alpha=0.5)
for idx in station_indices:
    values = data[str(idx)]
    ax.plot(data.time, values, label = stations[idx], linewidth=2, alpha =0.7)
    

leg = ax.legend()
print(ax)
ax.set_xlim(data.time.iloc[0], data.time.iloc[-1])
# ax.grid(which='major', color='b', linestyle='-')
ax.set_title("Temperature from barotropic run")
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%d-%Y'))
plt.show()
# ax.grid()
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
# pip install cartopy

# %%
hgrid =xr.open_dataset("//global/scratch/users/jennaisrael/run_schism/run_8/hgrid.nc")
hgrid.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.conda/envs/schimpy/lib/python3.7/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# ~/.conda/envs/schimpy/lib/python3.7/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('//global/scratch/users/jennaisrael/run_schism/run_8/hgrid.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_2129566/928898487.py in <module>
# ----> 1 hgrid =xr.open_dataset("//global/scratch/users/jennaisrael/run_schism/run_8/hgrid.nc")
#       2 hgrid.head()
#
# ~/.conda/envs/schimpy/lib/python3.7/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, backend_kwargs, *args, **kwargs)
#     497         drop_variables=drop_variables,
#     498         **decoders,
# --> 499         **kwargs,
#     500     )
#     501     ds = _dataset_from_backend_dataset(
#
# ~/.conda/envs/schimpy/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, lock, autoclose)
#     557             persist=persist,
#     558             lock=lock,
# --> 559             autoclose=autoclose,
#     560         )
#     561
#
# ~/.conda/envs/schimpy/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     377             netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     378         )
# --> 379         return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#     380
#     381     def _acquire(self, needs_lock=True):
#
# ~/.conda/envs/schimpy/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in __init__(self, manager, group, mode, lock, autoclose)
#     325         self._group = group
#     326         self._mode = mode
# --> 327         self.format = self.ds.data_model
#     328         self._filename = self.ds.filepath()
#     329         self.is_remote = is_remote_uri(self._filename)
#
# ~/.conda/envs/schimpy/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in ds(self)
#     386     @property
#     387     def ds(self):
# --> 388         return self._acquire()
#     389
#     390     def open_store_variable(self, name, var):
#
# ~/.conda/envs/schimpy/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in _acquire(self, needs_lock)
#     380
#     381     def _acquire(self, needs_lock=True):
# --> 382         with self._manager.acquire_context(needs_lock) as root:
#     383             ds = _nc4_require_group(root, self._group, self._mode)
#     384         return ds
#
# ~/.conda/envs/schimpy/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/.conda/envs/schimpy/lib/python3.7/site-packages/xarray/backends/file_manager.py in acquire_context(self, needs_lock)
#     185     def acquire_context(self, needs_lock=True):
#     186         """Context manager for acquiring a file."""
# --> 187         file, cached = self._acquire_with_cache_info(needs_lock)
#     188         try:
#     189             yield file
#
# ~/.conda/envs/schimpy/lib/python3.7/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     203                     kwargs = kwargs.copy()
#     204                     kwargs["mode"] = self._mode
# --> 205                 file = self._opener(*self._args, **kwargs)
#     206                 if self._mode == "w":
#     207                     # ensure file doesn't get overriden when opened again
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# OSError: [Errno -101] NetCDF: HDF error: b'//global/scratch/users/jennaisrael/run_schism/run_8/hgrid.nc'

# %%
# hgrid.make_plot(show=True)

import cartopy.crs as ccrs
import cartopy.feature as cfeature

from matplotlib.collections import PolyCollection
# axes.tricontourf(self.x, self.y, self.triangles, self.values, **kwargs)
# plt.tricontour(hgrid.x, hgrid.y,hgrid.triangles, velocity, levels=10)

fig = plt.figure() 
ax = plt.gca()
ax.tripcolor(hgrid.x, hgrid.y, hgrid.triangles, velocity+100, shading='flat', vmin=0, vmax = 0.4)

pc = PolyCollection(hgrid.coords[hgrid.quads])
# quad_value = np.mean(self.values[self.quads], axis=1)
# pc.set_array(quad_value)
pc.set_array(velocity)
ax.add_collection(pc)
            
            
# hgrid.quadface(ax=ax)
ax.set_xlim(550000, 650000)
# ax.axis([550000, 650000, 4.14e6, 4.3e6])
ax.axis("scaled")
cbar = plt.colorbar(pc, orientation="horizontal")
# hgrid.triplot()
# tricontourf(self, axes=None, show=True, figsize=None, **kwargs):
#         if len(self.triangles) > 0:
#             axes.tricontourf(self.x, self.y, self.triangles, self.values, **kwargs)
#         return axes

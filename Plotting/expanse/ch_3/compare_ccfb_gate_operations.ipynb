# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import cmocean
import matplotlib.dates as mdates
from matplotlib.lines import Line2D
# import datetime.datetime as datetime

# %%
# load the flux time series for each scenario
hist=pd.read_csv('/home/jisrael/BayDeltaSCHISM/data/time_history/ccfb_gate.th',sep=r'\s+',parse_dates=["datetime"],dtype=np.float32).set_index(["datetime"])
base=pd.read_csv('/home/jisrael/Savio_scratch_back_up/scenario_files/DCP/data/time_history/ccfb_gate_syn_historical.th',sep=r'\s+',parse_dates=["datetime"],dtype=np.float32).set_index(["datetime"])
dcp=pd.read_csv('/home/jisrael/Savio_scratch_back_up/scenario_files/DCP/data/time_history/ccfb_gate_syn_dcp_20260519.th',sep=r'\s+',parse_dates=["datetime"],dtype=np.float32).set_index(["datetime"])
cor=pd.read_csv('/home/jisrael/Savio_scratch_back_up/scenario_files/reserves/data/time_history/ccfb_gate_syn_cor_20260519.th',sep=r'\s+',parse_dates=["datetime"],dtype=np.float32).set_index(["datetime"])
base
# Out:
#                      install  ndup  op_down  op_up   elev  width  height
# datetime
# 2017-01-01 00:00:00      1.0   5.0      1.0    0.0 -4.024  6.096   0.305
# 2017-01-01 00:02:00      1.0   5.0      1.0    0.0 -4.024  6.096   0.610
# 2017-01-01 00:04:00      1.0   5.0      1.0    0.0 -4.024  6.096   0.914
# 2017-01-01 00:06:00      1.0   5.0      1.0    0.0 -4.024  6.096   2.438
# 2017-01-01 00:58:00      1.0   5.0      1.0    0.0 -4.024  6.096   2.438
# ...                      ...   ...      ...    ...    ...    ...     ...
# 2021-12-31 19:58:00      1.0   5.0      1.0    0.0 -4.024  6.096   0.000
# 2021-12-31 20:58:00      1.0   5.0      1.0    0.0 -4.024  6.096   0.000
# 2021-12-31 21:58:00      1.0   5.0      1.0    0.0 -4.024  6.096   0.000
# 2021-12-31 22:58:00      1.0   5.0      1.0    0.0 -4.024  6.096   0.000
# 2021-12-31 23:58:00      1.0   5.0      1.0    0.0 -4.024  6.096   0.000
#
# [253244 rows x 7 columns]

# %%
dcp
# Out:
#                      install  ndup  op_down  op_up   elev  width  height
# datetime
# 2017-01-01 00:00:00      1.0   5.0      1.0    0.0 -4.024  6.096   0.305
# 2017-01-01 00:02:00      1.0   5.0      1.0    0.0 -4.024  6.096   0.610
# 2017-01-01 00:04:00      1.0   5.0      1.0    0.0 -4.024  6.096   0.914
# 2017-01-01 00:06:00      1.0   5.0      1.0    0.0 -4.024  6.096   2.771
# 2017-01-01 00:08:00      1.0   5.0      1.0    0.0 -4.024  6.096   2.916
# ...                      ...   ...      ...    ...    ...    ...     ...
# 2021-12-31 19:58:00      1.0   5.0      1.0    0.0 -4.024  6.096   0.000
# 2021-12-31 20:58:00      1.0   5.0      1.0    0.0 -4.024  6.096   0.000
# 2021-12-31 21:58:00      1.0   5.0      1.0    0.0 -4.024  6.096   0.000
# 2021-12-31 22:58:00      1.0   5.0      1.0    0.0 -4.024  6.096   0.000
# 2021-12-31 23:58:00      1.0   5.0      1.0    0.0 -4.024  6.096   0.000
#
# [321367 rows x 7 columns]

# %%
fig, ax = plt.subplots(sharex=True, figsize=(10,4))

ax.plot(hist.height,label='historical')
ax.plot(base.height,label='synthetic historical')
ax.plot(dcp.height,label='dcp',linestyle='--')
ax.plot(cor.height,label='cor',linestyle='--')
ax.legend()
ax.set_xlim(pd.to_datetime("2018-10-1"),pd.to_datetime("2018-10-8"))
#ax[2].set_ylim(0,500)

ax.xaxis.set_major_formatter(mdates.ConciseDateFormatter(ax.xaxis.get_major_locator()))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b-%d'))
    # Rotates and right-aligns the x labels so they don't crowd each other.
for label in ax.get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')
fig.savefig('./figures/scenarios_ccfb_operations_20181001.png')

# %%
fig, ax = plt.subplots(sharex=True)

ax.plot(hist.height,label='historical')
ax.plot(base.height,label='synthetic historical')
ax.plot(dcp.height,label='dcp')
ax.plot(cor.height,label='cor')

ax.set_xlim(pd.to_datetime("2018-10-1"),pd.to_datetime("2021-9-30"))
#ax[2].set_ylim(0,500)

ax.xaxis.set_major_formatter(mdates.ConciseDateFormatter(ax.xaxis.get_major_locator()))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b-%d'))
    # Rotates and right-aligns the x labels so they don't crowd each other.
for label in ax.get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')

# %%
fig, ax = plt.subplots(sharex=True)

ax.plot(hist.height,label='historical')
ax.plot(base.height,label='synthetic historical')
ax.plot(dcp.height,label='dcp')
ax.plot(cor.height,label='cor')
ax.legend()
ax.set_xlim(pd.to_datetime("2018-10-1"),pd.to_datetime("2018-11-30"))
#ax[2].set_ylim(0,500)

ax.xaxis.set_major_formatter(mdates.ConciseDateFormatter(ax.xaxis.get_major_locator()))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b-%d'))
    # Rotates and right-aligns the x labels so they don't crowd each other.
for label in ax.get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')

# %%
fig, ax = plt.subplots(sharex=True, figsize=(10,4))

ax.plot(hist.height,label='historical')
ax.plot(base.height,label='synthetic historical')
ax.plot(dcp.height,label='dcp',linestyle='--')
ax.plot(cor.height,label='cor',linestyle='--')
ax.set_ylabel('Height [m]')

ax.set_xlim(pd.to_datetime("2019-01-1"),pd.to_datetime("2019-01-5"))
#ax[2].set_ylim(0,500)
ax.legend()
ax.xaxis.set_major_formatter(mdates.ConciseDateFormatter(ax.xaxis.get_major_locator()))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b-%d'))
    # Rotates and right-aligns the x labels so they don't crowd each other.
for label in ax.get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')
fig.savefig('./figures/scenarios_ccfb_operations_20190101.png')

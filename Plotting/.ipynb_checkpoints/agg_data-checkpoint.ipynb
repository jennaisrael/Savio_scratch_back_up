# %%
import numpy as np
import sys
import os, sys
import matplotlib.pyplot as plt
import xarray as xr
#from xarray import open_mfadataset
import cartopy.crs as crs
import cartopy
from matplotlib.colors import LogNorm
import numpy as np
import cartopy.io.shapereader as shpreader
from cartopy.feature import ShapelyFeature
import cmocean
import matplotlib
from pathlib import Path
import pandas as pd
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib import pyplot as plt
import rasterio
from rasterio.plot import show
from pyschism.mesh import Hgrid
import pyschism
from matplotlib.image import imread
import cmcrameri.cm as ccm
from matplotlib.collections import PolyCollection

print("Modules imported!")
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /global/home/users/jennaisrael/.conda/envs/schimpy/share/proj failed
# /global/home/users/jennaisrael/.conda/envs/schimpy/lib/python3.9/site-packages/pyschism/forcing/hycom/gofs.py:8: UserWarning: The seawater library is deprecated! Please use gsw instead.
#   import seawater as sw
# Modules imported!

# %%
#import Sienna's plotting library
import schism_plot_lib

# %%
output_folder='/global/scratch/users/jennaisrael/run_schism/run_8/outputs/'
output1=schism_plot_lib.SchismOutput(output_folder)
# Out:
#  Creating run object for results in /global/scratch/users/jennaisrael/run_schism/run_8/outputs/ ...
#
# Found 419 netcdf files!
# Found output for:
# 	 1 - horizontalVelX
# 	 2 - horizontalVelY
# 	 3 - hotstart
# 	 4 - out2d
# 	 5 - salinity
# 	 6 - temperature
# 	 7 - zCoordinates

# %%
files=output1.get_netcdf_files()
print(files)
# Out:
# Found 419 netcdf files!
# None

# %%
print(type(output1.files))
# Out:
# <class 'list'>

# %%
output1.get_types_of_output()
# Out:
# Found output for:
# 	 1 - horizontalVelX
# 	 2 - horizontalVelY
# 	 3 - hotstart
# 	 4 - out2d
# 	 5 - salinity
# 	 6 - temperature
# 	 7 - zCoordinates

# %%
var='salinity'
varfilenames=[f for f in output1.files if var in f]
print(varfilenames)
# Out:
# ['salinity_1.nc', 'salinity_10.nc', 'salinity_11.nc', 'salinity_12.nc', 'salinity_13.nc', 'salinity_14.nc', 'salinity_15.nc', 'salinity_16.nc', 'salinity_17.nc', 'salinity_18.nc', 'salinity_19.nc', 'salinity_2.nc', 'salinity_20.nc', 'salinity_21.nc', 'salinity_22.nc', 'salinity_23.nc', 'salinity_24.nc', 'salinity_25.nc', 'salinity_26.nc', 'salinity_27.nc', 'salinity_28.nc', 'salinity_29.nc', 'salinity_3.nc', 'salinity_4.nc', 'salinity_5.nc', 'salinity_6.nc', 'salinity_7.nc', 'salinity_8.nc', 'salinity_9.nc']

# %%
sal1=xr.open_dataset('/global/scratch/users/jennaisrael/run_schism/run_8/outputs/salinity_1.nc')
sal2=xr.open_dataset('/global/scratch/users/jennaisrael/run_schism/run_8/outputs/salinity_2.nc')
print(sal1)
print(sal2)
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:   (time: 48, nSCHISM_hgrid_node: 305834, nSCHISM_vgrid_layers: 23)
# Coordinates:
#   * time      (time) datetime64[ns] 384B 2018-02-15T16:30:00 ... 2018-02-16T1...
# Dimensions without coordinates: nSCHISM_hgrid_node, nSCHISM_vgrid_layers
# Data variables:
#     salinity  (time, nSCHISM_hgrid_node, nSCHISM_vgrid_layers) float32 1GB ...
# <xarray.Dataset> Size: 1GB
# Dimensions:   (time: 48, nSCHISM_hgrid_node: 305834, nSCHISM_vgrid_layers: 23)
# Coordinates:
#   * time      (time) datetime64[ns] 384B 2018-02-16T16:30:00 ... 2018-02-17T1...
# Dimensions without coordinates: nSCHISM_hgrid_node, nSCHISM_vgrid_layers
# Data variables:
#     salinity  (time, nSCHISM_hgrid_node, nSCHISM_vgrid_layers) float32 1GB ...

# %%
xr.merge([sal1,sal2])
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:   (time: 96, nSCHISM_hgrid_node: 305834, nSCHISM_vgrid_layers: 23)
# Coordinates:
#   * time      (time) datetime64[ns] 768B 2018-02-15T16:30:00 ... 2018-02-17T1...
# Dimensions without coordinates: nSCHISM_hgrid_node, nSCHISM_vgrid_layers
# Data variables:
#     salinity  (time, nSCHISM_hgrid_node, nSCHISM_vgrid_layers) float32 3GB na...

# %%
sal1.mean(dim='time').mean(dim='nSCHISM_vgrid_layers')
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:   (nSCHISM_hgrid_node: 305834)
# Dimensions without coordinates: nSCHISM_hgrid_node
# Data variables:
#     salinity  (nSCHISM_hgrid_node) float32 1MB 0.07262 0.07251 ... 0.333 0.3329

# %%
import glob

# %%
#ds = xarray.open_mfdataset('path/to/file/*.nc')
#salinity=xr.open_mfadataset(output_folder+'salinity_*.',)
#ds = xarray.merge([xarray.open_dataset(f) for f in glob.glob('path/to/file/.*nc')])

#salinity=xr.merge(['/global/scratch/users/jennaisrael/run_schism/run_8/outputs/salinity_1.nc','/global/scratch/users/jennaisrael/run_schism/run_8/outputs/salinity_2.nc'])
#this uses too much memory, try with just 2 files
#salinity=xr.merge([xr.open_dataset(f) for f in glob.glob('/global/scratch/users/jennaisrael/run_schism/run_8/outputs/salinity*')])

#still too much memory on slurm, try taking the depth average first
#initialize dataframe
salinity=xr.Dataset()
for f in glob.glob('/global/scratch/users/jennaisrael/run_schism/run_8/outputs/salinity*'):
    salinity=xr.merge([salinity, xr.open_dataset(f).mean(dim='nSCHISM_vgrid_layers')])
    
salinity.head()
# Out:
# <xarray.Dataset> Size: 140B
# Dimensions:   (time: 5, nSCHISM_hgrid_node: 5)
# Coordinates:
#   * time      (time) datetime64[ns] 40B 2018-02-15T16:30:00 ... 2018-02-15T18...
# Dimensions without coordinates: nSCHISM_hgrid_node
# Data variables:
#     salinity  (time, nSCHISM_hgrid_node) float32 100B 0.1144 0.1097 ... 0.07

# %%
print(salinity)
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:   (time: 1392, nSCHISM_hgrid_node: 305834)
# Coordinates:
#   * time      (time) datetime64[ns] 11kB 2018-02-15T16:30:00 ... 2018-03-16T1...
# Dimensions without coordinates: nSCHISM_hgrid_node
# Data variables:
#     salinity  (time, nSCHISM_hgrid_node) float32 2GB 0.1144 0.1097 ... 0.25 0.25

# %%
#plot_variable(self, schism_output, domain="SSC", time="average", depth="average")
plot_variable(output1, salinity

# %%
#make a plot of time averaged salinity, based on Sienna's plot_variable function 
 fig = plt.figure(figsize=(13,13))
            ax = plt.gca() 

            cmap = ccm.imola_r # cmocean.haline #

            # Add basemap 
            self.add_basemap(ax=ax)
    
            climit = climits[self.variable]
            args = {'vmin': climit[0], 'vmax': climit[1]}
            args['cmap'] = cmap

            ax.tripcolor(schism_output.hgrid.x, 
                            schism_output.hgrid.y, 
                            schism_output.hgrid.triangles, 
                            values, 
                            shading='flat', 
                            **args) #linewidth=0.2,
            pc = PolyCollection(schism_output.hgrid.coords[schism_output.hgrid.quads], clim=climit, cmap=cmap)
            quad_value = np.mean(values[schism_output.hgrid.quads], axis=1)  # THIS IS A CRITICAL STEP ... IT TURNS OUT 
            pc.set_array(quad_value)
            pc.set_edgecolor('face')
            ax.add_collection(pc)
            ax.grid(alpha = 0.25) 
            ax = self.set_domain(domain, ax)

            cbar = plt.colorbar(pc, orientation="horizontal", shrink=0.6)
            title = "SCHISM time-averaged %s at %s" % (var2title[self.variable], timestamp)
            t = ax.set_title(title)
            fn = "%s.png" % title.replace(":", "_")
            print(os.getcwd())
            fig.savefig(fn, dpi=300)
            print("Saved %s.\n\n" % fn)
